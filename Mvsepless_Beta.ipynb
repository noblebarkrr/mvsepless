# %% [markdown]
# # Установка

# %%
#@title # Установка (PIP, 3 минуты)
# %cd /content/
# !git clone https://github.com/noblebarkrr/mvsepless -b beta
# !cd mvsepless && pip install -r requirements.txt
# !cd mvsepless && pip install ./fixed/audio_separator-0.32.0-py3-none-any.whl

# %%
#@title # Установка (UV, 1 минута)
# %cd /content/
# !git clone https://github.com/noblebarkrr/mvsepless -b beta
# !pip install uv
# !cd mvsepless && uv pip install --no-cache-dir -qq -r requirements.txt
# !cd mvsepless && uv pip install --no-cache-dir -qq ./fixed/audio_separator-0.32.0-py3-none-any.whl

# %% [markdown]
# # MVSepLess Web-UI

# %%
import os
import re
import time
import urllib
import ipywidgets as widgets
from IPython.display import display, Javascript
import json
import socket
import psutil
import signal
import random
import string
# %cd /content/mvsepless

def generate_subdomain(length=8):
    """Генерация случайного субдомена заданной длины"""
    chars = string.ascii_lowercase + string.digits
    return ''.join(random.choice(chars) for _ in range(length))

def kill_process_using_port(port):
    """Находит и завершает процесс, использующий указанный порт"""
    for proc in psutil.process_iter(['pid', 'name', 'connections']):
        try:
            for conn in proc.connections():
                if conn.status == 'LISTEN' and conn.laddr.port == port:
                    print(f"Найден процесс {proc.name()} (PID: {proc.pid}), использующий порт {port}")
                    os.kill(proc.pid, signal.SIGTERM)
                    print(f"Процесс {proc.pid} завершен")
                    time.sleep(2)  # Даем время для освобождения порта
                    return True
        except (psutil.NoSuchProcess, psutil.AccessDenied, psutil.ZombieProcess):
            continue
    return False

# @markdown ## Запуск интерфейса
# @markdown  ---
# @markdown  ### Основные настройки веб интерфейса
port = 7860
# @markdown * Способы поделится приложением

# @markdown > Свойства \ Способ | ngrok | gradio | localtunnel
# @markdown > --- | --- | --- | ---
# @markdown > Требуется VPN | Да | Да | Нет
# @markdown > Стабильность | Высокая | Средняя | Низкая
# @markdown > Срок жизни ссылки | Бесконечный | 1 неделя | Пока субдомен не будет перехвачен
# @markdown <br>




share_method = "gradio" # @param ["ngrok","localtunnel","gradio"]
# @markdown * Язык
language = "ru" # @param ["ru","en"]
# @markdown ---
# @markdown ### Дополнительные настройки
# @markdown * Префикс субдомена для localtunnnel (Если пусто, то используется случайный субдомен по умолчанию)
lt_sub_domain = "mvsepless" # @param {"type":"string"}
# @markdown * Токен авторизации для ngrok\
# @markdown <small> Откуда можно взять токен (только с VPN в РФ): https://dashboard.ngrok.com/get-started/your-authtoken
ngrok_token = "" # @param {"type":"string"}
# @markdown * Путь к файлу шрифта в интерфейсе (.ttf, .otf, .woff, .eot)
font = "" # @param {"type":"string"}


# Проверяем занят ли порт и завершаем процесс
with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as s:
    if s.connect_ex(('localhost', port)) == 0:
        print(f"Порт {port} занят, пытаемся освободить...")
        if kill_process_using_port(port):
            print(f"Порт {port} успешно освобожден")
        else:
            print(f"Не удалось найти процесс, использующий порт {port}")
            print("Попробуйте другой порт или подождите несколько минут")
            exit()

if share_method == "localtunnel":
    os.system("npm install -g localtunnel &>/dev/null")
    time.sleep(7)
    with open('url.txt', 'w') as file:
        file.write('')
    subdomain = f"{re.sub(r'[^a-zA-Z0-9]', '', lt_sub_domain)}-{generate_subdomain(25)}"


    get_ipython().system_raw(
        f'lt --port {port} '
        f'{f"--subdomain {subdomain}" if lt_sub_domain != "" or lt_sub_domain.isspace() == False else ""} '
        '>> url.txt 2>&1 &'
    )
    time.sleep(3)
    try:
        endpoint_ip = urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip()
        with open('url.txt', 'r') as file:
            tunnel_url = file.read().replace("your url is: ", "").strip()
        print(f"Публичная ссылка: \033[93m{tunnel_url}\033[0m")
        print("НИКОМУ НЕ ПОКАЗЫВАЙТЕ ЭТУ ССЫЛКУ, А ТО МОГУТ ПЕРЕХВАТИТЬ СУБДОМЕН")

        text_field = widgets.Text(
            value=endpoint_ip,
            description='Пароль:',
            disabled=True
        )
        text_field.add_class("copy-enabled")

        display(text_field)
        display(Javascript("""
        setTimeout(() => {
            const input = document.querySelector('.copy-enabled input');
            if (!input) return;
            const btn = document.createElement('button');
            btn.innerHTML = '📋';
            btn.style.cssText = `
                margin-left: 8px;
                border: none;
                background: none;
                cursor: pointer;
                font-size: 1.2em;
            `;
            input.parentNode.appendChild(btn);
            btn.addEventListener('click', () => {
                navigator.clipboard.writeText(input);
                btn.innerHTML = '✓';
                setTimeout(() => btn.innerHTML = '📋', 2000);
            });
        }, 300);
        """))

    except Exception as e:
        print(f"Ошибка при старте localtunnel: {e}")

cmd_parts = [
    f"python app.py --lang {language} --port {port}",
    f" --share" if share_method == "gradio" else "",
    f" --ngrok_token {ngrok_token}" if share_method == "ngrok" else "",
    f" --font {font}" if font != "" else ""
]
cmd = "".join(cmd_parts)
print(f"Запускаем команду: {cmd}")
# !{cmd}

# %% [markdown]
# # MVSepLess CLI

# %%
#@title Инференс
#@markdown ---
#@markdown ### Входные данные
#@markdown * Путь к входной папке/файлу:
input_dir = "" # @param {type:"string"}
#@markdown ---
#@markdown ### Выбор модели
#@markdown * Тип модели:
model_type = "bs_roformer" # @param ["mel_band_roformer", "bs_roformer", "mdx23c", "scnet", "htdemucs", "bandit", "bandit_v2", "vr", "mdx"]
#@markdown * Название модели:
model_name = "BS-Roformer_SW" # @param {"type":"string"}
#@markdown ---
#@markdown ### Настройки раздления
# @markdown * Агрессивность для VR ARCH моделей
vr_arch_aggressive = 5 # @param {"type":"slider","min":1,"max":100,"step":1}
# @markdown * Извлечь  инструментал:
instrumental = False # @param {type:"boolean"}
#@markdown ---
#@markdown ### Выходные данные
#@markdown * Формат:
output_format = "mp3" # @param ["mp3", "wav", "flac", "ogg", "opus", "m4a", "aac", "aiff"]
# @markdown * Битрейт
bitrate = 320 # @param {"type":"slider","min":32,"max":320,"step":1}
# @markdown * Выбрать выходные стемы(через пробел, например ("vocal"  "instrumental")):
stems_to_extract = "" # @param {type:"string"}
#@markdown * Шаблон именования выходных файлов:
output_template = "NAME (STEM) MODEL" # @param {type:"string"}
#@markdown * Путь к выходной папке:
output_dir = "/content/output" # @param {type:"string"}
# @markdown * Показать список выходных файлов
show_list_outputs = True # @param {"type":"boolean"}

# %cd /content/mvsepless

cmd = [
    "python multi_inference.py separate",
    f"-i \"{input_dir}\"",
    f"-o \"{output_dir}\"",
    f"-mt \"{model_type}\"",
    f"-mn \"{model_name}\"",
    f"-of \"{output_format}\"",
    f"-bitrate \"{bitrate}k\"",
    f"-vr_aggr {vr_arch_aggressive}",
    f"--template \"{output_template}\""
]

if instrumental:
    cmd.append("--instrumental")

if show_list_outputs:
    cmd.append("-l_out")

if stems_to_extract:
    cmd.append(f"--stems {stems_to_extract}")

# !{" ".join(cmd)}
# Out:
# /content/mvsepless
# Starting inference: bs_roformer/BS-Roformer_SW, bitrate=126k, method=cli, stems=[]
# Model already downloaded
# Разделение выполняется на ядрах CUDA. Для выполнения на процессоре установите force_cpu=True.
# Используется устройство: cuda:0
# /usr/local/lib/python3.11/dist-packages/rotary_embedding_torch/rotary_embedding_torch.py:35: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# /usr/local/lib/python3.11/dist-packages/rotary_embedding_torch/rotary_embedding_torch.py:268: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# Выбранный чекпоинт: /content/mvsepless/separator/models_cache/bs_roformer/BS-Roformer_SW.ckpt
# Стемы: ['bass', 'drums', 'other', 'vocals', 'guitar', 'piano']
# Потрачено времени на загрузку модели: 5.74 сек.
# Выбранное аудио: /content/Galileo_call_Instrumental_Mel-Band-Roformer_Instrumental_Fv8b_gabox.mp3
# Выбранные стемы: None
# Стемы, которые будут сохранены: ['bass', 'drums', 'other', 'vocals', 'guitar', 'piano']
# /content/mvsepless/separator/msst_utils.py:233: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_amp):
# [Memory(location=None)]: Flushing completely the cache
# Потрачено времени: 18.81 сек.
# Модель выгружена из памяти
# Results
#
# Stem - bass
# Path - /content/output/Galileo_call_Instrumental_Mel-Band-Roformer_Instrumental_Fv8b_gabox (bass) BS-Roformer_SW.mp3
#
# Stem - drums
# Path - /content/output/Galileo_call_Instrumental_Mel-Band-Roformer_Instrumental_Fv8b_gabox (drums) BS-Roformer_SW.mp3
#
# Stem - other
# Path - /content/output/Galileo_call_Instrumental_Mel-Band-Roformer_Instrumental_Fv8b_gabox (other) BS-Roformer_SW.mp3
#
# Stem - vocals
# Path - /content/output/Galileo_call_Instrumental_Mel-Band-Roformer_Instrumental_Fv8b_gabox (vocals) BS-Roformer_SW.mp3
#
# Stem - guitar
# Path - /content/output/Galileo_call_Instrumental_Mel-Band-Roformer_Instrumental_Fv8b_gabox (guitar) BS-Roformer_SW.mp3
#
# Stem - piano
# Path - /content/output/Galileo_call_Instrumental_Mel-Band-Roformer_Instrumental_Fv8b_gabox (piano) BS-Roformer_SW.mp3

# %%
#@title Показать список моделей
filter = "" # @param {"type":"string"}
# %cd /content/mvsepless
cmd = f"python multi_inference.py list {f' -l_filter {filter}' if filter != '' else ''}"
# !$cmd
# Out:
# /content/mvsepless
#
# Available Models Information:
# ==================================================
#
# Model Type: MEL_BAND_ROFORMER
# --------------------------------------------------
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Model Name                                              | Stems        | Target Instrument   | Primary Stem   |
# +=========================================================+==============+=====================+================+
# | Mel-Band-Roformer_Vocals_kimberley_jensen               | vocals       | vocals              | N/A            |
# |                                                         | other        |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_InstVoc_Duality_v1_unwa               | Vocals       |                     | N/A            |
# |                                                         | Instrumental |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_InstVoc_Duality_v2_unwa               | Vocals       |                     | N/A            |
# |                                                         | Instrumental |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Kim_FT_v1_unwa                        | Vocals       | Vocals              | N/A            |
# |                                                         | other        |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Kim_FT_v2_unwa                        | vocals       | vocals              | N/A            |
# |                                                         | other        |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Kim_FT_v2_bleedless_unwa              | vocals       | vocals              | N/A            |
# |                                                         | other        |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Kim_FT_v3_prev_unwa                   | vocals       | vocals              | N/A            |
# |                                                         | other        |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Big_Beta_v1_unwa                      | vocals       | vocals              | N/A            |
# |                                                         | other        |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Big_Beta_v2_unwa                      | vocals       | vocals              | N/A            |
# |                                                         | other        |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Big_Beta_v3_unwa                      | vocals       | vocals              | N/A            |
# |                                                         | other        |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Big_Beta_v4_unwa                      | vocals       | vocals              | N/A            |
# |                                                         | other        |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Big_Beta_v5e_unwa                     | vocals       | vocals              | N/A            |
# |                                                         | other        |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Big_Beta_v6_unwa                      | vocals       | vocals              | N/A            |
# |                                                         | other        |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Big_Beta_v6x_unwa                     | vocals       | vocals              | N/A            |
# |                                                         | other        |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Instrumental_v1_unwa                  | vocals       | other               | N/A            |
# |                                                         | other        |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Instrumental_v1_plus_unwa             | vocals       | other               | N/A            |
# |                                                         | other        |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Instrumental_v1e_unwa                 | vocals       | other               | N/A            |
# |                                                         | other        |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Instrumental_v1e_plus_unwa            | vocals       | other               | N/A            |
# |                                                         | other        |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Instrumental_v2_unwa                  | vocals       | other               | N/A            |
# |                                                         | other        |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Small_v1_unwa                         | vocals       | vocals              | N/A            |
# |                                                         | other        |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Bleed_Suppressor_v1_unwa_97chris      | Instrumental | Instrumental        | N/A            |
# |                                                         | Bleed        |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Instrumental_becruliy                 | Vocals       | Instrumental        | N/A            |
# |                                                         | Instrumental |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Guitar_becruily                       | Guitar       | Guitar              | N/A            |
# |                                                         | Other        |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Karaoke_becruily                      | Vocals       |                     | N/A            |
# |                                                         | Instrumental |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Vocals_becruily                       | vocals       | vocals              | N/A            |
# |                                                         | other        |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_SYHFT_v1_syh99999                     | vocals       | vocals              | N/A            |
# |                                                         | other        |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_SYHFT_v2_syh99999                     | vocals       | vocals              | N/A            |
# |                                                         | other        |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_SYHFT_v2.5_syh99999                   | vocals       | vocals              | N/A            |
# |                                                         | other        |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_SYHFT_v3_syh99999                     | vocals       | vocals              | N/A            |
# |                                                         | other        |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_BIG_SYHFT_v1_Fast_syh99999            | vocals       | vocals              | N/A            |
# |                                                         | other        |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Merged_SYHFT_Beta_v1_syh99999         | vocals       | vocals              | N/A            |
# |                                                         | other        |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_SYHFT_B1_model1_syh99999              | vocals       | vocals              | N/A            |
# |                                                         | other        |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_SYHFT_B1_model2_syh99999              | vocals       | vocals              | N/A            |
# |                                                         | other        |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_SYHFT_B1_model3_syh99999              | vocals       | vocals              | N/A            |
# |                                                         | other        |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_4_stems_FT_Large_v1_syh99999          | vocals       |                     | N/A            |
# |                                                         | drums        |                     |                |
# |                                                         | bass         |                     |                |
# |                                                         | other        |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_4_stems_FT_Large_v2_syh99999          | vocals       |                     | N/A            |
# |                                                         | drums        |                     |                |
# |                                                         | bass         |                     |                |
# |                                                         | other        |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Instrumental_1652_essid               | Vocals       | Instrumental        | N/A            |
# |                                                         | Instrumental |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Instrumental_1681_essid               | Vocals       | Instrumental        | N/A            |
# |                                                         | Instrumental |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Instrumental_Fv1_gabox                | Vocals       | Instrumental        | N/A            |
# |                                                         | Instrumental |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Instrumental_Fv2_gabox                | Vocals       | Instrumental        | N/A            |
# |                                                         | Instrumental |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Instrumental_Fv3_gabox                | Vocals       | Instrumental        | N/A            |
# |                                                         | Instrumental |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Instrumental_Fv4N_gabox               | Vocals       | Instrumental        | N/A            |
# |                                                         | Instrumental |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Instrumental_Fv5_gabox                | Vocals       | Instrumental        | N/A            |
# |                                                         | Instrumental |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Instrumental_Fv5N_gabox               | Vocals       | Instrumental        | N/A            |
# |                                                         | Instrumental |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Instrumental_Fv6_gabox                | Vocals       | Instrumental        | N/A            |
# |                                                         | Instrumental |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Instrumental_Fv6N_gabox               | Vocals       | Instrumental        | N/A            |
# |                                                         | Instrumental |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Instrumental_Fv7_gabox                | Vocals       | Instrumental        | N/A            |
# |                                                         | Instrumental |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Instrumental_Fv7N_gabox               | Vocals       | Instrumental        | N/A            |
# |                                                         | Instrumental |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Instrumental_Fv7_plus_gabox           | Vocals       | Instrumental        | N/A            |
# |                                                         | Instrumental |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Instrumental_Fv7z_gabox               | Vocals       | Instrumental        | N/A            |
# |                                                         | Instrumental |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Instrumental_Fv8_gabox                | Vocals       | Instrumental        | N/A            |
# |                                                         | Instrumental |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Instrumental_Fv8b_gabox               | Vocals       | Instrumental        | N/A            |
# |                                                         | Instrumental |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Instrumental_Fv9_gabox                | Vocals       | Instrumental        | N/A            |
# |                                                         | Instrumental |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Instrumental_Fv10_gabox               | Vocals       | Instrumental        | N/A            |
# |                                                         | Instrumental |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Instrumental_FvX_gabox                | Vocals       | Instrumental        | N/A            |
# |                                                         | Instrumental |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Instrumental_Bv1_gabox                | Vocals       | Instrumental        | N/A            |
# |                                                         | Instrumental |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Instrumental_Bv2_gabox                | Vocals       | Instrumental        | N/A            |
# |                                                         | Instrumental |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Instrumental_Bv3_gabox                | Vocals       | Instrumental        | N/A            |
# |                                                         | Instrumental |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Vocals_Fv1_gabox                      | Vocals       | Vocals              | N/A            |
# |                                                         | Instrumental |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Vocals_Fv2_gabox                      | Vocals       | Vocals              | N/A            |
# |                                                         | Instrumental |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Vocals_Fv3_gabox                      | Vocals       | vocals              | N/A            |
# |                                                         | Instrumental |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Vocals_Fv4_gabox                      | Vocals       | Vocals              | N/A            |
# |                                                         | Instrumental |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Vocals_Fv5_gabox                      | Vocals       | Vocals              | N/A            |
# |                                                         | Instrumental |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Karaoke_25_02_2025_gabox              | karaoke      | karaoke             | N/A            |
# |                                                         | other        |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Karaoke_28_02_2025_gabox              | karaoke      | karaoke             | N/A            |
# |                                                         | other        |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Karaoke_v1_gabox                      | Vocals       | Vocals              | N/A            |
# |                                                         | Instrumental |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Karaoke_v2_gabox                      | Vocals       | Vocals              | N/A            |
# |                                                         | Instrumental |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Lead_Vocals_DeReverb_gabox            | Vocals       | Vocals              | N/A            |
# |                                                         | Instrumental |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Denoise_DeBleed_gabox                 | Vocals       | Instrumental        | N/A            |
# |                                                         | Instrumental |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Karaoke_Fusion_gonzaluigi             | Vocals       | Vocals              | N/A            |
# |                                                         | Instrumental |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Karaoke_Fusion_Aggr_gonzaluigi        | Vocals       | Vocals              | N/A            |
# |                                                         | Instrumental |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_BVE_gonzaluigi                        | Lead         | Lead                | N/A            |
# |                                                         | Back         |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Karaoke_Fusion_v2_Aggr_gonzaluigi     | Vocals       | Vocals              | N/A            |
# |                                                         | Instrumental |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Karaoke_Fusion_Total_gonzaluigi       | Vocals       | Vocals              | N/A            |
# |                                                         | Instrumental |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_DeReverb_anvuew                       | reverb       | noreverb            | N/A            |
# |                                                         | noreverb     |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_DeReverb_Less_Aggr_anvuew             | reverb       | noreverb            | N/A            |
# |                                                         | noreverb     |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_DeReverb_Mono_anvuew                  | reverb       | noreverb            | N/A            |
# |                                                         | noreverb     |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Aspiration_sucial                     | aspiration   |                     | N/A            |
# |                                                         | other        |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_DeReverb-Echo_v1_sucial               | dry          |                     | N/A            |
# |                                                         | other        |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_DeBigReverb_sucial                    | dry          | dry                 | N/A            |
# |                                                         | other        |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_DeSuperBigReverb_sucial               | dry          | dry                 | N/A            |
# |                                                         | other        |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_DeReverb-Echo_Fused_sucial            | dry          | dry                 | N/A            |
# |                                                         | other        |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_DeReverb-Echo_v2_sucial               | dry          | dry                 | N/A            |
# |                                                         | other        |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Karaoke_aufr33_viperx                 | karaoke      | karaoke             | N/A            |
# |                                                         | other        |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_DeNoise_aufr33                        | dry          | dry                 | N/A            |
# |                                                         | other        |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Denoise_Aggr_aufr33                   | dry          | dry                 | N/A            |
# |                                                         | other        |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Crowd_aufr33_viperx                   | crowd        | crowd               | N/A            |
# |                                                         | other        |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Vocals_viperx                         | vocals       | vocals              | N/A            |
# |                                                         | other        |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Vocals_Fullness_aname                 | vocals       | vocals              | N/A            |
# |                                                         | other        |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Kim_FT_v1_aname                       | vocals       | vocals              | N/A            |
# |                                                         | other        |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Kim_FT_v2_aname                       | vocals       | vocals              | N/A            |
# |                                                         | other        |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Kim_FT_v2_Fullness_aname              | vocals       | vocals              | N/A            |
# |                                                         | other        |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Kim_FT_v3_aname                       | vocals       | vocals              | N/A            |
# |                                                         | other        |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Small_aname                           | Vocals       |                     | N/A            |
# |                                                         | Instrumental |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_4_stems_Large_aname                   | vocals       |                     | N/A            |
# |                                                         | drums        |                     |                |
# |                                                         | bass         |                     |                |
# |                                                         | other        |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_4_stems_v2_Large_aname                | vocals       |                     | N/A            |
# |                                                         | drums        |                     |                |
# |                                                         | bass         |                     |                |
# |                                                         | other        |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_4_stems_XL_aname                      | vocals       |                     | N/A            |
# |                                                         | drums        |                     |                |
# |                                                         | bass         |                     |                |
# |                                                         | other        |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Drums_yolkispaliks                    | percussions  | percussions         | N/A            |
# |                                                         | other        |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
# | Mel-Band-Roformer_Instrumental_Metal_Preview_meskvlla33 | vocals       | other               | N/A            |
# |                                                         | other        |                     |                |
# +---------------------------------------------------------+--------------+---------------------+----------------+
#
#
# Model Type: BS_ROFORMER
# --------------------------------------------------
# +-------------------------------------------+--------------+---------------------+----------------+
# | Model Name                                | Stems        | Target Instrument   | Primary Stem   |
# +===========================================+==============+=====================+================+
# | BS-Roformer_Drums_beatloo_labs            | drums        | drums               | N/A            |
# |                                           | other        |                     |                |
# +-------------------------------------------+--------------+---------------------+----------------+
# | BS-Roformer_Bass_beatloo_labs             | bass         | bass                | N/A            |
# |                                           | other        |                     |                |
# +-------------------------------------------+--------------+---------------------+----------------+
# | BS-Roformer_Vocals_1296_viperx            | Vocals       | Vocals              | N/A            |
# |                                           | Instrumental |                     |                |
# +-------------------------------------------+--------------+---------------------+----------------+
# | BS-Roformer_Other_viperx                  | vocals       | other               | N/A            |
# |                                           | other        |                     |                |
# +-------------------------------------------+--------------+---------------------+----------------+
# | BS-Roformer_Revive_v1_unwa                | vocals       | vocals              | N/A            |
# |                                           | other        |                     |                |
# +-------------------------------------------+--------------+---------------------+----------------+
# | BS-Roformer_Revive_v2_unwa                | vocals       | vocals              | N/A            |
# |                                           | other        |                     |                |
# +-------------------------------------------+--------------+---------------------+----------------+
# | BS-Roformer_Revive_v3e_unwa               | vocals       | vocals              | N/A            |
# |                                           | other        |                     |                |
# +-------------------------------------------+--------------+---------------------+----------------+
# | BS-Roformer_Resurrection_unwa             | vocals       | vocals              | N/A            |
# |                                           | other        |                     |                |
# +-------------------------------------------+--------------+---------------------+----------------+
# | BS-Roformer_Resurrection_Inst_unwa        | vocals       | other               | N/A            |
# |                                           | other        |                     |                |
# +-------------------------------------------+--------------+---------------------+----------------+
# | BS-Roformer_VocTest_gabox                 | Vocals       | vocals              | N/A            |
# |                                           | Instrumental |                     |                |
# +-------------------------------------------+--------------+---------------------+----------------+
# | BS-Roformer_SW                            | bass         |                     | N/A            |
# |                                           | drums        |                     |                |
# |                                           | other        |                     |                |
# |                                           | piano        |                     |                |
# |                                           | guitar       |                     |                |
# |                                           | vocals       |                     |                |
# +-------------------------------------------+--------------+---------------------+----------------+
# | BS-Roformer_4_stems_zfturbo               | vocals       |                     | N/A            |
# |                                           | drums        |                     |                |
# |                                           | bass         |                     |                |
# |                                           | other        |                     |                |
# +-------------------------------------------+--------------+---------------------+----------------+
# | BS-Roformer_4_stems_FT_syh99999           | vocals       |                     | N/A            |
# |                                           | drums        |                     |                |
# |                                           | bass         |                     |                |
# |                                           | other        |                     |                |
# +-------------------------------------------+--------------+---------------------+----------------+
# | BS-Roformer_Chorus_Male-Female_146_sucial | male         |                     | N/A            |
# |                                           | female       |                     |                |
# +-------------------------------------------+--------------+---------------------+----------------+
# | BS-Roformer_Chorus_Male-Female_267_sucial | male         |                     | N/A            |
# |                                           | female       |                     |                |
# +-------------------------------------------+--------------+---------------------+----------------+
# | BS-Roformer_Male-Female_aufr33            | male         |                     | N/A            |
# |                                           | female       |                     |                |
# +-------------------------------------------+--------------+---------------------+----------------+
# | BS-Roformer_Deverb_256_8_anvuew           | reverb       | noreverb            | N/A            |
# |                                           | noreverb     |                     |                |
# +-------------------------------------------+--------------+---------------------+----------------+
# | BS-Roformer_Deverb_384_10_anvuew          | reverb       | noreverb            | N/A            |
# |                                           | noreverb     |                     |                |
# +-------------------------------------------+--------------+---------------------+----------------+
# | BS-Roformer_4_stems_aname                 | vocals       |                     | N/A            |
# |                                           | drums        |                     |                |
# |                                           | bass         |                     |                |
# |                                           | other        |                     |                |
# +-------------------------------------------+--------------+---------------------+----------------+
#
#
# Model Type: MDX23C
# --------------------------------------------------
# +---------------------------------+--------------+---------------------+----------------+
# | Model Name                      | Stems        | Target Instrument   | Primary Stem   |
# +=================================+==============+=====================+================+
# | MDX23C_InstVoc_HQ_zfturbo       | vocals       |                     | N/A            |
# |                                 | other        |                     |                |
# +---------------------------------+--------------+---------------------+----------------+
# | MDX23C_8kFFT_InstVoc_HQ_v1      | Vocals       |                     | N/A            |
# |                                 | Instrumental |                     |                |
# +---------------------------------+--------------+---------------------+----------------+
# | MDX23C_8kFFT_InstVoc_HQ_v2      | Vocals       |                     | N/A            |
# |                                 | Instrumental |                     |                |
# +---------------------------------+--------------+---------------------+----------------+
# | MDX23C_D1581                    | Vocals       |                     | N/A            |
# |                                 | Instrumental |                     |                |
# +---------------------------------+--------------+---------------------+----------------+
# | MDX23C_DrumSep_aufr33_jarredou  | kick         |                     | N/A            |
# |                                 | snare        |                     |                |
# |                                 | toms         |                     |                |
# |                                 | hh           |                     |                |
# |                                 | ride         |                     |                |
# |                                 | crash        |                     |                |
# +---------------------------------+--------------+---------------------+----------------+
# | MDX23C_DeReverb_aufr33_jarredou | dry          | dry                 | N/A            |
# |                                 | other        |                     |                |
# +---------------------------------+--------------+---------------------+----------------+
# | MDX23C_Mid_Side_wesleyr36       | similarity   | similarity          | N/A            |
# |                                 | difference   |                     |                |
# +---------------------------------+--------------+---------------------+----------------+
# | MDX23C_4_stems_zfturbo          | vocals       |                     | N/A            |
# |                                 | drums        |                     |                |
# |                                 | bass         |                     |                |
# |                                 | other        |                     |                |
# +---------------------------------+--------------+---------------------+----------------+
# | MDX23C_Orchestra_verosment      | inst         | orch                | N/A            |
# |                                 | orch         |                     |                |
# +---------------------------------+--------------+---------------------+----------------+
#
#
# Model Type: SCNET
# --------------------------------------------------
# +-----------------------------------------+---------+---------------------+----------------+
# | Model Name                              | Stems   | Target Instrument   | Primary Stem   |
# +=========================================+=========+=====================+================+
# | SCNet_4_stems_zfturbo                   | vocals  |                     | N/A            |
# |                                         | drums   |                     |                |
# |                                         | bass    |                     |                |
# |                                         | other   |                     |                |
# +-----------------------------------------+---------+---------------------+----------------+
# | SCNet_XL_IHF_4_stems_zfturbo            | vocals  |                     | N/A            |
# |                                         | drums   |                     |                |
# |                                         | bass    |                     |                |
# |                                         | other   |                     |                |
# +-----------------------------------------+---------+---------------------+----------------+
# | SCNet_XL_4_stems_starrytong             | vocals  |                     | N/A            |
# |                                         | drums   |                     |                |
# |                                         | bass    |                     |                |
# |                                         | other   |                     |                |
# +-----------------------------------------+---------+---------------------+----------------+
# | SCNet_XL_4_stems_zftrubo                | vocals  |                     | N/A            |
# |                                         | drums   |                     |                |
# |                                         | bass    |                     |                |
# ...
# |                                | No Breath    |                     |                |
# +--------------------------------+--------------+---------------------+----------------+
# | UVR-De-Breath-sucial-v2        | Breath       |                     | Breath         |
# |                                | No Breath    |                     |                |
# +--------------------------------+--------------+---------------------+----------------+
# | VR_Harmonic_Noise_Sep          | Noise        |                     | Noise          |
# |                                | No Noise     |                     |                |
# +--------------------------------+--------------+---------------------+----------------+
#
#
# Model Type: MDX
# --------------------------------------------------
# +---------------------------+--------------+---------------------+----------------+
# | Model Name                | Stems        | Target Instrument   | Primary Stem   |
# +===========================+==============+=====================+================+
# | UVR-MDX-NET-Inst_HQ_1     | Instrumental |                     | N/A            |
# |                           | Vocals       |                     |                |
# +---------------------------+--------------+---------------------+----------------+
# | UVR-MDX-NET-Inst_HQ_2     | Instrumental |                     | N/A            |
# |                           | Vocals       |                     |                |
# +---------------------------+--------------+---------------------+----------------+
# | UVR-MDX-NET-Inst_HQ_3     | Instrumental |                     | N/A            |
# |                           | Vocals       |                     |                |
# +---------------------------+--------------+---------------------+----------------+
# | UVR-MDX-NET-Inst_HQ_4     | Instrumental |                     | N/A            |
# |                           | Vocals       |                     |                |
# +---------------------------+--------------+---------------------+----------------+
# | UVR-MDX-NET-Inst_HQ_5     | Instrumental |                     | N/A            |
# |                           | Vocals       |                     |                |
# +---------------------------+--------------+---------------------+----------------+
# | UVR_MDXNET_Main           | Vocals       |                     | N/A            |
# |                           | Instrumental |                     |                |
# +---------------------------+--------------+---------------------+----------------+
# | UVR-MDX-NET-Inst_Main     | Instrumental |                     | N/A            |
# |                           | Vocals       |                     |                |
# +---------------------------+--------------+---------------------+----------------+
# | UVR_MDXNET_1_9703         | Vocals       |                     | N/A            |
# |                           | Instrumental |                     |                |
# +---------------------------+--------------+---------------------+----------------+
# | UVR_MDXNET_2_9682         | Vocals       |                     | N/A            |
# |                           | Instrumental |                     |                |
# +---------------------------+--------------+---------------------+----------------+
# | UVR_MDXNET_3_9662         | Vocals       |                     | N/A            |
# |                           | Instrumental |                     |                |
# +---------------------------+--------------+---------------------+----------------+
# | UVR-MDX-NET-Inst_1        | Instrumental |                     | N/A            |
# |                           | Vocals       |                     |                |
# +---------------------------+--------------+---------------------+----------------+
# | UVR-MDX-NET-Inst_2        | Instrumental |                     | N/A            |
# |                           | Vocals       |                     |                |
# +---------------------------+--------------+---------------------+----------------+
# | UVR-MDX-NET-Inst_3        | Instrumental |                     | N/A            |
# |                           | Vocals       |                     |                |
# +---------------------------+--------------+---------------------+----------------+
# | UVR_MDXNET_KARA           | Vocals       |                     | N/A            |
# |                           | Instrumental |                     |                |
# +---------------------------+--------------+---------------------+----------------+
# | UVR_MDXNET_KARA_2         | Instrumental |                     | N/A            |
# |                           | Vocals       |                     |                |
# +---------------------------+--------------+---------------------+----------------+
# | UVR_MDXNET_9482           | Vocals       |                     | N/A            |
# |                           | Instrumental |                     |                |
# +---------------------------+--------------+---------------------+----------------+
# | UVR-MDX-NET-Voc_FT        | Vocals       |                     | N/A            |
# |                           | Instrumental |                     |                |
# +---------------------------+--------------+---------------------+----------------+
# | Kim_Vocal_1               | Vocals       |                     | N/A            |
# |                           | Instrumental |                     |                |
# +---------------------------+--------------+---------------------+----------------+
# | Kim_Vocal_2               | Vocals       |                     | N/A            |
# |                           | Instrumental |                     |                |
# +---------------------------+--------------+---------------------+----------------+
# | Kim_Inst                  | Instrumental |                     | N/A            |
# |                           | Vocals       |                     |                |
# +---------------------------+--------------+---------------------+----------------+
# | Reverb_HQ_By_FoxJoy       | Reverb       |                     | N/A            |
# |                           | No Reverb    |                     |                |
# +---------------------------+--------------+---------------------+----------------+
# | UVR-MDX-NET_Crowd_HQ_1    | No Crowd     |                     | N/A            |
# |                           | Crowd        |                     |                |
# +---------------------------+--------------+---------------------+----------------+
# | kuielab_a_vocals          | Vocals       |                     | N/A            |
# |                           | Instrumental |                     |                |
# +---------------------------+--------------+---------------------+----------------+
# | kuielab_a_other           | Other        |                     | N/A            |
# |                           | No Other     |                     |                |
# +---------------------------+--------------+---------------------+----------------+
# | kuielab_a_bass            | Bass         |                     | N/A            |
# |                           | No Bass      |                     |                |
# +---------------------------+--------------+---------------------+----------------+
# | kuielab_a_drums           | Drums        |                     | N/A            |
# |                           | No Drums     |                     |                |
# +---------------------------+--------------+---------------------+----------------+
# | kuielab_b_vocals          | Vocals       |                     | N/A            |
# |                           | Instrumental |                     |                |
# +---------------------------+--------------+---------------------+----------------+
# | kuielab_b_other           | Other        |                     | N/A            |
# |                           | No Other     |                     |                |
# +---------------------------+--------------+---------------------+----------------+
# | kuielab_b_bass            | Bass         |                     | N/A            |
# |                           | No Bass      |                     |                |
# +---------------------------+--------------+---------------------+----------------+
# | kuielab_b_drums           | Drums        |                     | N/A            |
# |                           | No Drums     |                     |                |
# +---------------------------+--------------+---------------------+----------------+
# | UVR-MDX-NET_Main_340      | Vocals       |                     | N/A            |
# |                           | Instrumental |                     |                |
# +---------------------------+--------------+---------------------+----------------+
# | UVR-MDX-NET_Main_390      | Vocals       |                     | N/A            |
# |                           | Instrumental |                     |                |
# +---------------------------+--------------+---------------------+----------------+
# | UVR-MDX-NET_Main_406      | Vocals       |                     | N/A            |
# |                           | Instrumental |                     |                |
# +---------------------------+--------------+---------------------+----------------+
# | UVR-MDX-NET_Main_427      | Vocals       |                     | N/A            |
# |                           | Instrumental |                     |                |
# +---------------------------+--------------+---------------------+----------------+
# | UVR-MDX-NET_Main_438      | Vocals       |                     | N/A            |
# |                           | Instrumental |                     |                |
# +---------------------------+--------------+---------------------+----------------+
# | UVR-MDX-NET_Inst_82_beta  | Instrumental |                     | N/A            |
# |                           | Vocals       |                     |                |
# +---------------------------+--------------+---------------------+----------------+
# | UVR-MDX-NET_Inst_90_beta  | Instrumental |                     | N/A            |
# |                           | Vocals       |                     |                |
# +---------------------------+--------------+---------------------+----------------+
# | UVR-MDX-NET_Inst_187_beta | Instrumental |                     | N/A            |
# |                           | Vocals       |                     |                |
# +---------------------------+--------------+---------------------+----------------+
# | UVR-MDX-NET-Inst_full_292 | Instrumental |                     | N/A            |
# |                           | Vocals       |                     |                |
# +---------------------------+--------------+---------------------+----------------+
#
#
# Model Type: HTDEMUCS
# --------------------------------------------------
# +------------------------------+------------+---------------------+----------------+
# | Model Name                   | Stems      | Target Instrument   | Primary Stem   |
# +==============================+============+=====================+================+
# | HTDemucs4_MVSep_vocals       | vocals     |                     | N/A            |
# |                              | other      |                     |                |
# +------------------------------+------------+---------------------+----------------+
# | HTDemucs4                    | vocals     |                     | N/A            |
# |                              | drums      |                     |                |
# |                              | bass       |                     |                |
# |                              | other      |                     |                |
# +------------------------------+------------+---------------------+----------------+
# | HTDemucs4_6s                 | vocals     |                     | N/A            |
# |                              | drums      |                     |                |
# |                              | bass       |                     |                |
# |                              | other      |                     |                |
# |                              | guitar     |                     |                |
# |                              | piano      |                     |                |
# +------------------------------+------------+---------------------+----------------+
# | Demucs3_mmi                  | vocals     |                     | N/A            |
# |                              | drums      |                     |                |
# |                              | bass       |                     |                |
# |                              | other      |                     |                |
# +------------------------------+------------+---------------------+----------------+
# | HTDemucs4_FT_Bass            | vocals     |                     | N/A            |
# |                              | drums      |                     |                |
# |                              | bass       |                     |                |
# |                              | other      |                     |                |
# +------------------------------+------------+---------------------+----------------+
# | HTDemucs4_FT_Drums           | vocals     |                     | N/A            |
# |                              | drums      |                     |                |
# |                              | bass       |                     |                |
# |                              | other      |                     |                |
# +------------------------------+------------+---------------------+----------------+
# | HTDemucs4_FT_Vocals          | vocals     |                     | N/A            |
# |                              | drums      |                     |                |
# |                              | bass       |                     |                |
# |                              | other      |                     |                |
# +------------------------------+------------+---------------------+----------------+
# | HTDemucs4_FT_Other           | vocals     |                     | N/A            |
# |                              | drums      |                     |                |
# |                              | bass       |                     |                |
# |                              | other      |                     |                |
# +------------------------------+------------+---------------------+----------------+
# | HTDemucs4_Mid_Side_wesleyr36 | similarity |                     | N/A            |
# |                              | difference |                     |                |
# +------------------------------+------------+---------------------+----------------+
#
#
# Model Type: BANDIT
# --------------------------------------------------
# +--------------+---------+---------------------+----------------+
# | Model Name   | Stems   | Target Instrument   | Primary Stem   |
# +==============+=========+=====================+================+
# | Bandit_Plus  | speech  |                     | N/A            |
# |              | music   |                     |                |
# |              | effects |                     |                |
# +--------------+---------+---------------------+----------------+
#
#
# Model Type: BANDIT_V2
# --------------------------------------------------
# +-----------------+---------+---------------------+----------------+
# | Model Name      | Stems   | Target Instrument   | Primary Stem   |
# +=================+=========+=====================+================+
# | Bandit_v2_Multi | speech  |                     | N/A            |
# |                 | music   |                     |                |
# |                 | sfx     |                     |                |
# +-----------------+---------+---------------------+----------------+
