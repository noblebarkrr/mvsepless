# %%
import subprocess


class Test:
    def __init__(self):
        self.output_formats = (
            "mp3",
            "wav",
            "flac",
            "ogg",
            "opus",
            "m4a",
            "aac",
            "ac3",
            "aiff",
        )
        self.input_formats = (
            "mp3",
            "wav",
            "flac",
            "ogg",
            "opus",
            "m4a",
            "aac",
            "ac3",
            "aiff",
            "mp4",
            "mkv",
            "webm",
            "avi",
            "mov",
            "ts",
        )
        self.bitrate_limit = {
            "mp3": {"min": 8, "max": 320},
            "aac": {"min": 8, "max": 512},
            "m4a": {"min": 8, "max": 512},
            "ac3": {"min": 32, "max": 640},
            "ogg": {"min": 32, "max": 500},
            "opus": {"min": 6, "max": 512},
        }
        self.sample_rates = {
            "mp3": {
                "supported": (
                    44100,
                    48000,
                    32000,
                    22050,
                    24000,
                    16000,
                    11025,
                    12000,
                    8000,
                )
            },
            "opus": {"supported": (48000, 24000, 16000, 12000, 8000)},
            "m4a": {
                "supported": (
                    96000,
                    88200,
                    64000,
                    48000,
                    44100,
                    32000,
                    24000,
                    22050,
                    16000,
                    12000,
                    11025,
                    8000,
                    7350,
                )
            },
            "aac": {
                "supported": (
                    96000,
                    88200,
                    64000,
                    48000,
                    44100,
                    32000,
                    24000,
                    22050,
                    16000,
                    12000,
                    11025,
                    8000,
                    7350,
                )
            },
            "ac3": {
                "supported": (
                    48000,
                    44100,
                    32000,
                )
            },
            "ogg": {"min": 6, "max": 50000},
            "wav": {"min": 0, "max": float("inf")},
            "aiff": {"min": 0, "max": float("inf")},
            "flac": {"min": 0, "max": 192000},
        }

max_hz = 50000
max_bitrate_channels1 = 240
max_bitrate_channels2 = 480
max_bitrate_channels3 = 720
max_bitrate_channels4 = 960

channels = 2

ffmpeg = "ffmpeg"
input_file = ""
output_file = ""
